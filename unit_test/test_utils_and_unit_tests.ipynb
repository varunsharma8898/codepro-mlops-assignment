# %%
import pandas as pd
import os
import sqlite3
import sys
from sqlite3 import Error

# sys.path.append('../')
from constants import *
from data_validation_checks import *
from city_tier_mapping import *
from significant_categorical_level import *
from utils import *

# %%
print(DB_PATH)
print(DB_FILE_NAME)
print(DATA_DIRECTORY)
print(INTERACTION_MAPPING)
# Out:
# utils_output.db
#
# interaction_mapping.csv

# %%
build_dbs()
# Out:
# DB Already Exists
# /Users/varunssharma/codepro-mlops-assignment/Assignment/01_data_pipeline/scripts/unit_test
# 'DB Exists'

# %%
load_data_into_db()
# Out:
# loaded_data already populated

# %%
map_city_tier()
# Out:
# city_tier_mapped already populated

# %%
map_categorical_vars()
# Out:
# categorical_variables_mapped already Stored

# %%
interactions_mapping()
# Out:
# model_input and interactions_mapped already stored

# %%
from test_with_pytest import *

# %%
# !pip install pytest
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/Users/varunssharma/.pyenv/versions/3.7.12/bin/python3.7 -m pip install --upgrade pip' command.

# %%
print(UNIT_TEST_DB_FILE_NAME)
# Out:
# unit_test_cases.db

# %%
test_load_data_into_db()
# Out:
# DB Already Exists
# /Users/varunssharma/codepro-mlops-assignment/Assignment/01_data_pipeline/scripts/unit_test
# loaded_data already populated

# %%
connection = sqlite3.connect(DB_PATH + DB_FILE_NAME)
df = pd.read_sql('select * from loaded_data', connection)

# %%
df
# Out:
#            created_date city_mapped first_platform_c first_utm_medium_c  \
# 0   2021-11-19 15:25:38    ghazipur           Level3             Level0
# 1   2021-08-24 15:17:20      murbad           Level3             Level0
# 2   2021-07-20 16:01:20      mumbai          Level14             Level2
# 3   2021-09-04 14:00:42   bengaluru           Level7             Level0
# 4   2022-01-13 05:41:45         ncr           Level8            Level16
# ..                  ...         ...              ...                ...
# 95  2022-01-19 11:18:46        None           Level2             Level2
# 96  2021-12-12 14:14:12       banka           Level2            Level18
# 97  2021-09-07 15:44:36        None           Level1            Level19
# 98  2022-01-16 15:38:15     chennai           Level0            Level11
# 99  2021-11-12 07:02:01         ncr           Level0             Level1
#
#    first_utm_source_c  total_leads_droppped  referred_lead  \
# ...

# %%
connection.close()
connection = sqlite3.connect(UNIT_TEST_DB_FILE_NAME)
ref_df = pd.read_sql('select * from loaded_data_test_case order by created_date, city_mapped', connection)

# %%
ref_df
# Out:
#            created_date city_mapped first_platform_c first_utm_medium_c  \
# 0   2021-07-01 07:32:25      mumbai           Level3            Level31
# 1   2021-07-05 04:26:31      mumbai           Level2             Level6
# 2   2021-07-08 11:28:20         ncr           Level7             Level3
# 3   2021-07-11 05:39:39   gopalganj           Level3             Level0
# 4   2021-07-12 16:56:30   hyderabad           Level3             Level0
# ..                  ...         ...              ...                ...
# 95  2022-02-02 13:57:52       kochi           Level8            Level13
# 96  2022-02-09 07:14:35   hyderabad           Level7             Level2
# 97  2022-02-10 08:28:30     lucknow           Level0             Level1
# 98  2022-02-11 09:00:25   bengaluru          Level26            Level13
# 99  2022-02-11 09:50:05         ncr           Level0             Level4
#
#    first_utm_source_c  total_leads_droppped  referred_lead  \
# ...

# %%
test_map_city_tier()
# Out:
# DB Already Exists
# /Users/varunssharma/codepro-mlops-assignment/Assignment/01_data_pipeline/scripts/unit_test
# loaded_data already populated
# city_tier_mapped already populated

# %%
test_map_categorical_vars()
# Out:
# DB Already Exists
# /Users/varunssharma/codepro-mlops-assignment/Assignment/01_data_pipeline/scripts/unit_test
# loaded_data already populated
# city_tier_mapped already populated
# categorical_variables_mapped already Stored

# %%
test_interactions_mapping()
# Out:
# DB Already Exists
# /Users/varunssharma/codepro-mlops-assignment/Assignment/01_data_pipeline/scripts/unit_test
# loaded_data already populated
# city_tier_mapped already populated
# categorical_variables_mapped already Stored
# model_input and interactions_mapped already stored
